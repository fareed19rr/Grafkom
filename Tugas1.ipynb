# %%
from graphics import *
def main():
    win = GraphWin("Tugas 1 Grafkom",720,720)
    
    c = Circle(Point(360,120),70)
    r1 = Rectangle(Point(0,0), Point(720,360))
    c.setFill('Yellow')
    r1.setFill('Light Blue')
    r2 = Rectangle(Point(0,360), Point(720,720))
    r2.setFill('Light Green')
    
    jalan = Rectangle(Point(320, 360),Point(400,720))
    jalan.setFill('Grey')
    
    titik1 = Point(0,360)
    titik2 = Point(180,60)
    titik3 = Point(360,360)
    
    gunung1 = Polygon(titik1,titik2,titik3)
    gunung1.setFill('Green')
    
    titik4 = Point(360,360)
    titik5 = Point(540,60)
    titik6 = Point(720,360)
    
    gunung2 = Polygon(titik4,titik5,titik6)
    gunung2.setFill('Green')
    
    kolam1 = Rectangle(Point(460, 700), Point(700,600))
    kolam1.setFill('Blue')
    
    kolam2 = Rectangle(Point(20,700), Point(260,600))
    kolam2.setFill('Blue')
    
    PR11 = Point(100,400)
    PR12 = Point(200,400)
    PR13 = Point(50,420)
    PR14 = Point(250,420)
    
    atap1 = Polygon(PR11,PR13,PR14,PR12)
    atap1.setFill('Red')
    
    PR21 = Point(520,400)
    PR22 = Point(470,420)
    PR23 = Point(670,420)
    PR24 = Point(620,400)
    
    atap2 = Polygon(PR21,PR22,PR23,PR24)
    atap2.setFill('Red')
    
    bangunan1 = Rectangle(Point(50,420),Point(250,480))
    bangunan1.setFill(color_rgb(245,245,220))
    
    bangunan2 = Rectangle(Point(470,420),Point(670,480))
    bangunan2.setFill(color_rgb(245,245,220))
    
    pintu1 = Rectangle(Point(130,440),Point(170,480))
    pintu1.setFill('Brown')
    
    pintu2 = Rectangle(Point(550,440),Point(590,480))
    pintu2.setFill('Brown')
    
    kaca11 = Rectangle(Point(75,440),Point(105,460))
    kaca11.setFill('Light Blue')
    
    kaca12 = Rectangle(Point(195,440),Point(225,460))
    kaca12.setFill('Light Blue')
    
    kaca21 = Rectangle(Point(495,440),Point(525,460))
    kaca21.setFill('Light Blue')
    
    kaca22 = Rectangle(Point(615,440),Point(645,460))
    kaca22.setFill('Light Blue')
    
    r1.draw(win)
    r2.draw(win)
    bangunan1.draw(win)
    bangunan2.draw(win)
    kaca11.draw(win)
    kaca12.draw(win)
    kaca21.draw(win)
    kaca22.draw(win)
    pintu1.draw(win)
    pintu2.draw(win)
    atap1.draw(win)
    atap2.draw(win)
    kolam1.draw(win)
    kolam2.draw(win)
    gunung2.draw(win)
    gunung1.draw(win)
    jalan.draw(win)
    c.draw(win)
    win.getMouse()
    win.close()
main()

# %% [markdown]
# ###
